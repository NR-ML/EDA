# %%
# %cd C:\Users\nirma\Downloads\Python Datasets
# Out:
# C:\Users\nirma\Downloads\Python Datasets

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('C:\\Users\\nirma\\Downloads\\Python Datasets\\pokemon.csv')

# %%
sns.countplot(data=df,x='generation_id')
# Out:
# <AxesSubplot:xlabel='generation_id', ylabel='count'>

# %%
base_color=sns.color_palette("pastel")[2]
sns.countplot(data=df,x='generation_id',color=base_color)
# Out:
# <AxesSubplot:xlabel='generation_id', ylabel='count'>

# %%
base_color=sns.color_palette()[4]
gen_order=df['generation_id'].value_counts().index
sns.countplot(data=df,x='generation_id',color=base_color,order=gen_order)
# Out:
# <AxesSubplot:xlabel='generation_id', ylabel='count'>

# %%
sns.countplot(data=df,x='type_1',color=base_color)
plt.xticks(rotation=90);

# %%
sns.countplot(data=df,y='type_1',color=base_color)
# Out:
# <AxesSubplot:xlabel='count', ylabel='type_1'>

# %%
missing=df.isna().sum()

# %%
sns.barplot(x=missing.index.values,y=missing)
plt.xticks(rotation=90);
