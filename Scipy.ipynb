# %%
import numpy as np
import scipy
from scipy import linalg

# %%
a=np.array([(5,4),(6,3)])

# %%
a
# Out:
# array([[5, 4],
#        [6, 3]])

# %%
scipy.linalg.eig(a)
# Out:
# (array([ 9.+0.j, -1.+0.j]),
#  array([[ 0.70710678, -0.5547002 ],
#         [ 0.70710678,  0.83205029]]))

# %%
# %cd C:\Users\nirma\Downloads\Wallpapers
# Out:
# C:\Users\nirma\Downloads\Wallpapers

# %%
from PIL import Image

# %%
b=Image.open(r"C:\Users\nirma\Downloads\Wallpapers\m4h2hhjze8w71.png")

# %%
display(b.resize((int(b.size[0]/3),int(b.size[1]/3)), 0) )
# Out:
# <PIL.Image.Image image mode=RGB size=640x360 at 0x2301FA56C40>

# %%
img=np.array(Image.open(r"C:\Users\nirma\Downloads\Wallpapers\m4h2hhjze8w71.png"))

# %%
img
# Out:
# array([[[19,  2, 43],
#         [19,  2, 43],
#         [19,  2, 43],
#         ...,
#         [19,  2, 43],
#         [19,  2, 43],
#         [19,  2, 43]],
#
#        [[19,  2, 43],
#         [19,  2, 43],
#         [19,  2, 43],
#         ...,
#         [19,  2, 43],
#         [19,  2, 43],
#         [19,  2, 43]],
#
#        [[19,  2, 43],
#         [19,  2, 43],
#         [19,  2, 43],
#         ...,
#         [19,  2, 43],
#         [19,  2, 43],
#         [19,  2, 43]],
#
#        ...,
#
#        [[43,  0, 72],
#         [43,  0, 72],
#         [43,  0, 72],
#         ...,
#         [43,  0, 72],
#         [43,  0, 72],
#         [43,  0, 72]],
#
#        [[42,  0, 72],
#         [42,  0, 72],
#         [42,  0, 72],
#         ...,
#         [42,  0, 72],
#         [42,  0, 72],
#         [42,  0, 72]],
#
#        [[42,  0, 72],
#         [42,  0, 72],
#         [42,  0, 72],
#         ...,
#         [42,  0, 72],
#         [42,  0, 72],
#         [42,  0, 72]]], dtype=uint8)

# %%
img.shape
# Out:
# (1080, 1920, 3)

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
img.ndim
# Out:
# 3

# %%
img[:,:,0].min()
# Out:
# 0

# %%
img[20,20]
# Out:
# array([19,  2, 43], dtype=uint8)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20520/3743618818.py in <module>
# ----> 1 b=b.convert(RGBchannel('R'))
#       2 Gc=display(b.get)
#
# NameError: name 'RGBchannel' is not defined

# %%
Rc=display(b.getchannel('R'))
Gc=display(b.getchannel('G'))
Bc=display(b.getchannel('B'))
# Out:
# <PIL.Image.Image image mode=L size=1920x1080 at 0x2301DFA12B0>
# <PIL.Image.Image image mode=L size=1920x1080 at 0x2301FA66160>
# <PIL.Image.Image image mode=L size=1920x1080 at 0x2301DFA12B0>

# %%
import matplotlib.pyplot as plt

# %%
np.concatenate(display(b.getchannel('R')),display(b.getchannel('G')),display(b.getchannel('B')))
# Out:
# <PIL.Image.Image image mode=L size=1920x1080 at 0x23020E09B50>
# <PIL.Image.Image image mode=L size=1920x1080 at 0x2301F9C6D00>
# <PIL.Image.Image image mode=L size=1920x1080 at 0x2301F9C6D00>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20520/3103141952.py in <module>
# ----> 1 np.concatenate(display(b.getchannel('R')),display(b.getchannel('G')),display(b.getchannel('B')))
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# TypeError: dispatcher for __array_function__ did not return an iterable

# %%
A=scipy.flipud(b)
# Out:
# C:\Users\nirma\AppData\Local\Temp/ipykernel_20520/1131398243.py:1: DeprecationWarning: scipy.flipud is deprecated and will be removed in SciPy 2.0.0, use numpy.flipud instead
#   A=scipy.flipud(b)

# %%
A
# Out:
# array([[[42,  0, 72],
#         [42,  0, 72],
#         [42,  0, 72],
#         ...,
#         [42,  0, 72],
#         [42,  0, 72],
#         [42,  0, 72]],
#
#        [[42,  0, 72],
#         [42,  0, 72],
#         [42,  0, 72],
#         ...,
#         [42,  0, 72],
#         [42,  0, 72],
#         [42,  0, 72]],
#
#        [[43,  0, 72],
#         [43,  0, 72],
#         [43,  0, 72],
#         ...,
#         [43,  0, 72],
#         [43,  0, 72],
#         [43,  0, 72]],
#
#        ...,
#
#        [[19,  2, 43],
#         [19,  2, 43],
#         [19,  2, 43],
#         ...,
#         [19,  2, 43],
#         [19,  2, 43],
#         [19,  2, 43]],
#
#        [[19,  2, 43],
#         [19,  2, 43],
#         [19,  2, 43],
#         ...,
#         [19,  2, 43],
#         [19,  2, 43],
#         [19,  2, 43]],
#
#        [[19,  2, 43],
#         [19,  2, 43],
#         [19,  2, 43],
#         ...,
#         [19,  2, 43],
#         [19,  2, 43],
#         [19,  2, 43]]], dtype=uint8)

# %%
B=img.flatten()

# %%
plt.hist(B, bins=200,range=[0,256])
plt.title("Number of pixels in each intensity value")
plt.xlabel("Intensity")
plt.ylabel("Number of pixels")
plt.show()
